# %% [raw]
# https://doi.org/10.15468/dl.atht7q

# %%
from dwca.read import DwCAReader

# %%
dwca = '/home/aubrey/Downloads/0052622-210914110416597.zip'

# %%
with DwCAReader(dwca) as dwca:
    print("Core data file is: {}".format(dwca.descriptor.core.file_location)) # => 'occurrence.txt'
    core_df = dwca.pd_read('occurrence.txt', parse_dates=True)
core_df.dropna(how='all', axis=1, inplace=True)
core_df
# Out:
# Core data file is: occurrence.txt
#             id                                         identifier  license  \
# 0   3399821302  394C6E68FFAC3E7DE1EEFCC5FD09F78B.mc.018DD523FF...  CC0_1_0
# 1   3399821301  394C6E68FFAC3E7DE1EEFCC5FD09F78B.mc.018DD523FF...  CC0_1_0
# 2   3399820310  394C6E68FFAD3E7CE142F87EFBD0F634.mc.018DD523FF...  CC0_1_0
# 3   3399820309  394C6E68FFAC3E7DE1EEFCC5FD09F78B.mc.018DD523FF...  CC0_1_0
# 4   3399820308  394C6E68FFAD3E7CE140FCCEFDFEF828.mc.018DD523FF...  CC0_1_0
# 5   3399820307  394C6E68FFAD3E7CE140FCCEFDFEF828.mc.018DD523FF...  CC0_1_0
# 6   3399820306  394C6E68FFAC3E7DE1EEFCC5FD09F78B.mc.018DD523FF...  CC0_1_0
# 7   3399820305  394C6E68FFAC3E7DE1EEFCC5FD09F78B.mc.018DD523FF...  CC0_1_0
# 8   3399820304  394C6E68FFAD3E7CE142F87EFBD0F634.mc.018DD523FF...  CC0_1_0
# 9   3399820303  394C6E68FFAD3E7CE140FCCEFDFEF828.mc.018DD523FF...  CC0_1_0
# 10  3399820301  394C6E68FFAD3E7CE140FCCEFDFEF828.mc.018DD523FF...  CC0_1_0
# ...
