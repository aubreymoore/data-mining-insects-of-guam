# %%
from pygbif import occurrences, species
import pandas as pd

# %% [raw]
# #set parameters for API call
# params = ['limit=300', 'genusKey=3152178', 'hasCoordinate=true',
# 'hasGeospatialIssue=false']
# #Set up a simple while loop to continue downloading until the last #page
# df = pd.DataFrame()
# endOfRecords = False
# offset = 0
# status = 200
# while endOfRecords == False and status == 200:
#     df, endOfRecords, status = get_GBIF_response(base_url, offset, params, df)
#     offset = len(df) + 1

# %%
key = species.name_backbone(name = 'Aphididae', rank='Family')['usageKey']

occs = occurrences.search(taxonKey=key, country='GU', offset=0, limit=10)
occs

# df = pd.DataFrame()
# endOfRecords = False
# while endOfRecords == False:
#     occs = occurrences.search(taxonKey=key, country='GU', offset=0)
    
#     endOfRecords = occs['endOfRecords']
# Out:
# {'offset': 0,
#  'limit': 10,
#  'endOfRecords': False,
#  'count': 175,
#  'results': [{'key': 3349838997,
#    'datasetKey': 'd8cd16ba-bb74-4420-821e-083f2bac17c2',
#    'publishingOrgKey': 'ada9d123-ddb4-467d-8891-806ea8d94230',
#    'installationKey': '17a83780-3060-4851-9d6f-029d5fcb81c9',
#    'publishingCountry': 'GB',
#    'protocol': 'EML',
#    'lastCrawled': '2023-01-28T12:07:46.173+00:00',
#    'lastParsed': '2023-01-28T12:31:12.258+00:00',
#    'crawlId': 68,
#    'hostingOrganizationKey': 'fbca90e3-8aed-48b1-84e3-369afbd000ce',
#    'extensions': {},
#    'basisOfRecord': 'PRESERVED_SPECIMEN',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 6259947,
#    'kingdomKey': 1,
#    'phylumKey': 54,
#    'classKey': 216,
#    'orderKey': 809,
#    'familyKey': 3042,
#    'genusKey': 2074687,
#    'speciesKey': 9766680,
#    'acceptedTaxonKey': 9766680,
#    'scientificName': 'Pentalonia nigronervosa caladii van der Goot, 1917',
# ...

# %%
pd.DataFrame.from_dict(occs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.DataFrame.from_dict(occs)
#
# File ~/myenv/lib/python3.9/site-packages/pandas/core/frame.py:1763, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1757     raise ValueError(
#    1758         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1759         f"Got '{orient}' instead"
#    1760     )
#    1762 if orient != "tight":
# -> 1763     return cls(data, index=index, columns=columns, dtype=dtype)
#    1764 else:
#    1765     realdata = data["data"]
#
# File ~/myenv/lib/python3.9/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
# ...
