# %%
from pygbif import registry

# %%
# Fulltext search for all datasets having the word "amsterdam" somewhere in
# its metadata (title, description, etc).
registry.dataset_search(type="CHECKLIST", q="Insects of Guam")
# Out:
# {'offset': 0,
#  'limit': 100,
#  'endOfRecords': False,
#  'count': 36841,
#  'results': [{'key': '592c9898-f961-4f9b-a833-5de174eb834b',
#    'title': 'Neuropteroid Insects from Guam',
#    'doi': '10.5281/zenodo.5159923',
#    'description': 'This dataset contains the digitized treatments in Plazi based on the original book chapter Banks, Nathan (1942): Neuropteroid Insects from Guam. In: Insects of Guam I. Honolulu, Hawaii: Bernice P. Bishop Museum: 25-30, DOI: http://doi.org/10.5281/zenodo.5159923',
#    'type': 'CHECKLIST',
#    'hostingOrganizationKey': '7ce8aef0-9e92-11dc-8738-b8a03c50a862',
#    'hostingOrganizationTitle': 'Plazi.org taxonomic treatments database',
#    'hostingCountry': 'CH',
#    'publishingCountry': 'CH',
#    'publishingOrganizationKey': '7ce8aef0-9e92-11dc-8738-b8a03c50a862',
#    'publishingOrganizationTitle': 'Plazi.org taxonomic treatments database',
#    'endorsingNodeKey': 'ffb07bec-2d10-492d-9c37-361fe0b79427',
# ...
